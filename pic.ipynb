# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("Octoqueer.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1000, 1000, 3)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x1000 at 0x21306A12460>

# %%
cut = arr[:5, :5]

# %%
plt.imshow(cut)
